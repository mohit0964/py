# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Emp_Records  (1).csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# dropna it is used to drop null values
# axis = 0 -- it will drop the rows which consist null values df1 = df.dropna(axis=0)
# aixi = 1 -- it will drop the columns which consist null values = df2 = df.dropna(axis=1)

# %%
df1 = df.dropna(axis =0)
df1

# %%
df2 = df.dropna(axis=1)
df2

# %% [markdown]
# fillna -used ti fill the null values
# df1= df.fillna(100)
# df['Weight in Kgs'].mean()
# df['Weight in Kgs'].median()
# df['Weight in Kgs'].fillna(56, inplace=True)
#
# try to fill null values ["Age in Company"] using mean,median
# df['Age in Company'].fillna(df['Age in Company'].mean(), inplace=True)
# df

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     3
# Age in Company    1
# Salary            0
# City              1
# dtype: int64

# %%
df1 =df.fillna(100)
df1
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36          100.0           13.68  168251
# 1   940761     Brenda       47.02          100.0          100.00   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67          100.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            100
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df['Weight in Kgs'].mean()
# Out:
# 58.11340206185567

# %%
df['Weight in Kgs'].median()
# Out:
# 56.0

# %%
df['Weight in Kgs'].fillna(56, inplace=True)
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           56.0           13.68  168251
# 1   940761     Brenda       47.02           56.0             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           56.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df['Weight in Kgs'].fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Weight in Kgs'].fillna(df.mean())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# ...

# %% [markdown]
# # value_counts() = it gives the count of all the differnt values in the column.
# df['City'].value_counts()

# %%
df['City'].value_counts() # it gives the count of all the differnt values in the column.
# Out:
# City
# Stonewall       1
# Albion          1
# Eckert          1
# Haswell         1
# Kansas City     1
#                ..
# Kline           1
# Panacea         1
# Mesa            1
# Lawrenceburg    1
# Alma            1
# Name: count, Length: 99, dtype: int64

# %%
df2=pd.read_csv("Iris .csv")
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df2['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # unique() -it gives us the list of unique elements in the feature
# df['City'].unique()

# %%
df2["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["City"].unique()
# Out:
# array([nan, 'Stonewall', 'Michigantown', 'Hydetown', 'Fremont',
#        'Macksburg', 'Atlanta', 'Blanchester', 'Delmita', 'Eureka Springs',
#        'Sabetha', 'Las Vegas', 'New Matamoras', 'Maida', 'Quecreek',
#        'Beulaville', 'New Douglas', 'Toeterville', 'Primm Springs',
#        'Dutchtown', 'Shreveport', 'Heathsville', 'Middleport', 'Woodbury',
#        'Saint Cloud', 'Stockholm', 'Manning', 'Mount Vernon',
#        'Lawrenceburg', 'Mesa', 'Panacea', 'Kline', 'Bonanza', 'Liberty',
#        'Ohatchee', 'Nashville', 'Eckerty', 'Lima', 'Wright', 'Ellsworth',
#        'Conroy', 'Lake Charles', 'Kalvesta', 'Knoxville', 'Rochester',
#        'Bowling Green', 'Uniontown', 'Topeka', 'New York City', 'Banner',
#        'East Saint Louis', 'Hancock', 'Eatontown', 'Portage', 'Oneida',
#        'Bartley', 'Arlee', 'Cookeville', 'Saxe', 'Mc Calla', 'Trego',
#        'Blair', 'Riverside', 'Maxwell', 'Randallstown', 'Willow Beach',
# ...

# %%
len(df["City"].unique())
# Out:
# 100
